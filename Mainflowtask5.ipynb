# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("heart.csv")

# %%
df
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#histograms of all numeric values
df.hist(bins = 50, grid = False, figsize = (20,15))
plt.show()

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
questions = ["1. How many people have heart disease and how many people doesn't have heart disease?",
             "2. people of which sex has most heart disease?",
             "3. people of which sex has which type of chest pain most?",
             "4. people with which chest pain are most prone to have heart disease?",
             "5. Most common type of chest pain?",
             "6. What is the most common cholesterol level (chol) in the dataset?",
             "7. What is the average resting blood pressure (trestbps) among the individuals??"]
questions
# Out:
# ["1. How many people have heart disease and how many people doesn't have heart disease?",
#  '2. people of which sex has most heart disease?',
#  '3. people of which sex has which type of chest pain most?',
#  '4. people with which chest pain are most prone to have heart disease?',
#  '5. Most common type of chest pain?',
#  '6. What is the most common cholesterol level (chol) in the dataset?',
#  '7. What is the average resting blood pressure (trestbps) among the individuals??']

# %%
#1. How many people have heart disease and how many people doesn't have heart disease?

x = df.target.value_counts()
x
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
x.plot(kind = "bar", color=["red","green"])
plt.title("Heart disease Value")
plt.xlabel('1 = Heart disease,  0 = No Heart disease')
plt.ylabel("Amount")
# Out:
# Text(0, 0.5, 'Amount')

# %% [markdown]
# # 526 people have heart disease and 499 do not have

# %%
#piechart 
x.plot(kind = "pie", figsize = (8,6))
plt.legend(["Disease", "No Disease"]);

# %%
#"0" represent "Female"

# "1" represent "Male"

# "0" represent "No disease"

# "1" represent "Disease"

#2. people of which sex has most heart disease?
df.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
#piechart for male and female ratio 
df.sex.value_counts().plot(kind = "pie", figsize = (6,4))
plt.title("Male and Female ratio")
plt.legend(["Male","Female"])

# %%
#2. people of which sex has most heart disease?
pd.crosstab(df.target, df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
sns.countplot(x = "target", data = df, hue = "sex")
plt.title("Heart Disease Frequency for sex")
plt.xlabel("0 = No heart disease, 1= Heart disease")
plt.show()

# %% [markdown]
# # Among females, a higher number of individuals have heart disease (226) compared to those without (86).
# # Among males, a higher number of individuals do not have heart disease (413) compared to those who do (300).

# %%
#numbe of male is more than double in our dataset than female.
#more than 45% male has heart disease and 75% female has heart disease

# %% [markdown]
# 3 . people of which sex has which type of chest pain most?

# %%
#counting values for different chest pain 
df.cp.value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
df.cp.value_counts().plot(kind = "bar", color = ["salmon", "purple", "green", "brown"])
plt.title("Chest pain VS count")
plt.show()

# %%
pd.crosstab(df.sex, df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(df.sex, df.cp).plot(kind = "bar", color = ["coral", "blue", "brown", "pink"])
plt.title("People of which sex have which type of chest pain most")
plt.xlabel("0 = Female,  1 = Male");

# %%
# mosy of "male" has "type 0 " chest pain and least of "type 3" pain.
#incase of "Female" "type 0" and "type 2" percentage is almost same

# %% [markdown]
# 4 .People with which chest pain are most prone to have heart disease?

# %%
pd.crosstab(df.cp, df.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
sns.countplot(x= "cp", data = df, hue = "target")
# Out:
# <Axes: xlabel='cp', ylabel='count'>

# %%
#Most of the people who has "type 0" chest pain has less chance of heart disease.
# and opposite for other types

# %%
#distribution plot with normal distribution curve
sns.displot(x = "age", data = df, bins = 30, kde = True);
# Out:
# C:\Users\rasto\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# 58-59 year old people are most in the dataset

# %%
#distribution plot for "Maximum heart rate"
sns.displot(x = "thalach", data = df, bins = 30, kde = True, color = "brown")
plt.show()
# Out:
# C:\Users\rasto\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#5 Most common type of chest pain

# %%
cp_order = df['cp'].value_counts().index
cp_order
# Out:
# Index([0, 2, 1, 3], dtype='int64', name='cp')

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='cp', data=df, order=cp_order, palette='viridis')
plt.title('Frequency of Chest Pain Types')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.show()

# %%
#6 What is the most common cholesterol level (chol) in the dataset?

# %%
# Find the most common cholesterol level (chol)
most_common_chol = df['chol'].mode()[0]

# Plotting the distribution of 'chol'
plt.figure(figsize=(8, 6))
sns.histplot(df['chol'], kde=True, color='lightgreen', bins=10)

# Highlight the most common cholesterol level

plt.axvline(most_common_chol, color='red', linestyle='-', linewidth=1)
plt.text(most_common_chol + 1, 1, f'Mode: {most_common_chol}', color='red')

# Add titles and labels
plt.title('Distribution of Cholesterol Levels (chol)')
plt.xlabel('Cholesterol Level (chol)')
plt.ylabel('Frequency')

# Show the plot
plt.show()

# %%
#7 What is the average resting blood pressure (trestbps) among the individuals?
average_trestbps = df['trestbps'].mean()

# Plotting the distribution of 'trestbps'
plt.figure(figsize=(10, 6))
sns.histplot(df['trestbps'], kde=True, color='lightcoral', bins=10)

# Highlight the average resting blood pressure
plt.axvline(average_trestbps, color='blue', linestyle='--', linewidth=2, label=f'Average: {average_trestbps:.2f}')
plt.text(average_trestbps + 1, 1, f'Average: {average_trestbps:.2f}', color='blue')

# Add titles and labels
plt.title('Distribution of Resting Blood Pressure (trestbps)')
plt.xlabel('Resting Blood Pressure (trestbps)')
plt.ylabel('Frequency')
plt.legend()

# Show the plot
plt.show()
